# %% [markdown]
# ## Google COVID-19 Community Mobility Report data

# %%
import pandas as pd
import numpy as np

# %%
london_2020 = pd.read_csv("../data_sources/google/2020_GB_Region_Mobility_Report.csv")
london_2020 = london_2020.loc[london_2020.sub_region_1=='Greater London']
london_2020
# Out:
#       country_region_code  country_region    sub_region_1  \
# 36253                  GB  United Kingdom  Greater London
# 36254                  GB  United Kingdom  Greater London
# 36255                  GB  United Kingdom  Greater London
# 36256                  GB  United Kingdom  Greater London
# 36257                  GB  United Kingdom  Greater London
# ...                   ...             ...             ...
# 47162                  GB  United Kingdom  Greater London
# 47163                  GB  United Kingdom  Greater London
# 47164                  GB  United Kingdom  Greater London
# 47165                  GB  United Kingdom  Greater London
# 47166                  GB  United Kingdom  Greater London
#
#                                 sub_region_2  metro_area iso_3166_2_code  \
# 36253                                    NaN         NaN             NaN
# 36254                                    NaN         NaN             NaN
# ...

# %%
london_2021 = pd.read_csv("../data_sources/google/2021_GB_Region_Mobility_Report.csv")
london_2021 = london_2021.loc[london_2021.sub_region_1=='Greater London']
london_2021
# Out:
#       country_region_code  country_region    sub_region_1  \
# 25276                  GB  United Kingdom  Greater London
# 25277                  GB  United Kingdom  Greater London
# 25278                  GB  United Kingdom  Greater London
# 25279                  GB  United Kingdom  Greater London
# 25280                  GB  United Kingdom  Greater London
# ...                   ...             ...             ...
# 32819                  GB  United Kingdom  Greater London
# 32820                  GB  United Kingdom  Greater London
# 32821                  GB  United Kingdom  Greater London
# 32822                  GB  United Kingdom  Greater London
# 32823                  GB  United Kingdom  Greater London
#
#                                 sub_region_2  metro_area iso_3166_2_code  \
# 25276                                    NaN         NaN             NaN
# 25277                                    NaN         NaN             NaN
# ...

# %%
london_2020[london_2020.sub_region_2.isna()]
# Out:
#       country_region_code  country_region    sub_region_1 sub_region_2  \
# 36253                  GB  United Kingdom  Greater London          NaN
# 36254                  GB  United Kingdom  Greater London          NaN
# 36255                  GB  United Kingdom  Greater London          NaN
# 36256                  GB  United Kingdom  Greater London          NaN
# 36257                  GB  United Kingdom  Greater London          NaN
# ...                   ...             ...             ...          ...
# 36569                  GB  United Kingdom  Greater London          NaN
# 36570                  GB  United Kingdom  Greater London          NaN
# 36571                  GB  United Kingdom  Greater London          NaN
# 36572                  GB  United Kingdom  Greater London          NaN
# 36573                  GB  United Kingdom  Greater London          NaN
#
#        metro_area iso_3166_2_code  census_fips_code  \
# 36253         NaN             NaN               NaN
# ...

# %%
greater_london = pd.concat([london_2020[london_2020.sub_region_2.isna()],
                            london_2021[london_2021.sub_region_2.isna()]]) 
greater_london
# Out:
#       country_region_code  country_region    sub_region_1 sub_region_2  \
# 36253                  GB  United Kingdom  Greater London          NaN
# 36254                  GB  United Kingdom  Greater London          NaN
# 36255                  GB  United Kingdom  Greater London          NaN
# 36256                  GB  United Kingdom  Greater London          NaN
# 36257                  GB  United Kingdom  Greater London          NaN
# ...                   ...             ...             ...          ...
# 25493                  GB  United Kingdom  Greater London          NaN
# 25494                  GB  United Kingdom  Greater London          NaN
# 25495                  GB  United Kingdom  Greater London          NaN
# 25496                  GB  United Kingdom  Greater London          NaN
# 25497                  GB  United Kingdom  Greater London          NaN
#
#        metro_area iso_3166_2_code  census_fips_code  \
# 36253         NaN             NaN               NaN
# ...

# %%
greater_london.drop(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
                     'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id'], axis=1, inplace=True)
greater_london.set_index('date', inplace=True)
greater_london = greater_london.loc[:'2021-07-31']  # Removing dates beyond July 31
greater_london
# Out:
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-02-15                                              -11.0
# 2020-02-16                                               -9.0
# 2020-02-17                                               11.0
# 2020-02-18                                                4.0
# 2020-02-19                                                3.0
# ...                                                       ...
# 2021-07-27                                              -29.0
# 2021-07-28                                              -32.0
# 2021-07-29                                              -25.0
# 2021-07-30                                              -33.0
# 2021-07-31                                              -33.0
#
#             grocery_and_pharmacy_percent_change_from_baseline  \
# date
# 2020-02-15                                               -8.0
# 2020-02-16                                              -11.0
# ...

# %%
greater_london.to_csv('../datasets/google_london.csv')

# %%
hong_kong = pd.concat((pd.read_csv("../data_sources/google/2020_HK_Region_Mobility_Report.csv"),
                            pd.read_csv("../data_sources/google/2021_HK_Region_Mobility_Report.csv")))
hong_kong.drop(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
                     'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id'], axis=1, inplace=True)
hong_kong.set_index('date', inplace=True)
hong_kong = hong_kong.loc[:'2021-07-31']
hong_kong
# Out:
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-02-15                                                -26
# 2020-02-16                                                -28
# 2020-02-17                                                -23
# 2020-02-18                                                -24
# 2020-02-19                                                -24
# ...                                                       ...
# 2021-07-27                                                 -7
# 2021-07-28                                                 -7
# 2021-07-29                                                 -8
# 2021-07-30                                                 -6
# 2021-07-31                                                 -7
#
#             grocery_and_pharmacy_percent_change_from_baseline  \
# date
# 2020-02-15                                                 -4
# 2020-02-16                                                -12
# ...

# %%
hong_kong.to_csv('../datasets/google_hong_kong.csv')

# %%
new_york_2020 = pd.read_csv("../data_sources/google/2020_US_Region_Mobility_Report.csv")
new_york_2020 = new_york_2020[(new_york_2020.sub_region_1 == 'New York') & (new_york_2020.sub_region_2 == 'New York County')]
new_york_2021 = pd.read_csv("../data_sources/google/2021_US_Region_Mobility_Report.csv")
new_york_2021 = new_york_2021[(new_york_2021.sub_region_1 == 'New York') & (new_york_2021.sub_region_2 == 'New York County')]
new_york = pd.concat((new_york_2020, new_york_2021))
new_york.drop(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
                     'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id'], axis=1, inplace=True)
new_york.set_index('date', inplace=True)
new_york = new_york.loc[:'2021-07-31']
new_york
# Out:
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-02-15                                                2.0
# 2020-02-16                                                6.0
# 2020-02-17                                               -5.0
# 2020-02-18                                                0.0
# 2020-02-19                                                2.0
# ...                                                       ...
# 2021-07-27                                              -41.0
# 2021-07-28                                              -40.0
# 2021-07-29                                              -46.0
# 2021-07-30                                              -40.0
# 2021-07-31                                              -36.0
#
#             grocery_and_pharmacy_percent_change_from_baseline  \
# date
# 2020-02-15                                               -5.0
# 2020-02-16                                               -2.0
# ...

# %%
new_york.to_csv('../datasets/google_new_york.csv')

# %%
sydney_2020 = pd.read_csv("../data_sources/google/2020_AU_Region_Mobility_Report.csv")
sydney_2020 = sydney_2020.loc[(sydney_2020.sub_region_1 == 'New South Wales') & (sydney_2020.sub_region_2 == 'Council of the City of Sydney')]
sydney_2021 = pd.read_csv("../data_sources/google/2021_AU_Region_Mobility_Report.csv")
sydney_2021 = sydney_2021.loc[(sydney_2021.sub_region_1 == 'New South Wales') & (sydney_2021.sub_region_2 == 'Council of the City of Sydney')]
sydney = pd.concat((sydney_2020, sydney_2021))
sydney.drop(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
                     'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id'], axis=1, inplace=True)
sydney.set_index('date', inplace=True)
sydney = sydney.loc[:'2021-07-31']
sydney
# Out:
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-02-15                                                6.0
# 2020-02-16                                                2.0
# 2020-02-17                                               -1.0
# 2020-02-18                                                3.0
# 2020-02-19                                                2.0
# ...                                                       ...
# 2021-07-27                                              -80.0
# 2021-07-28                                              -81.0
# 2021-07-29                                              -81.0
# 2021-07-30                                              -80.0
# 2021-07-31                                              -77.0
#
#             grocery_and_pharmacy_percent_change_from_baseline  \
# date
# 2020-02-15                                                9.0
# 2020-02-16                                               13.0
# ...

# %%
sydney.to_csv('../datasets/google_sydney.csv')

# %%
# First lockdown
greater_london.loc['2020-03-23':'2020-05-13'].mean()
# Out:
# retail_and_recreation_percent_change_from_baseline   -79.653846
# grocery_and_pharmacy_percent_change_from_baseline    -33.653846
# parks_percent_change_from_baseline                   -17.326923
# transit_stations_percent_change_from_baseline        -76.403846
# workplaces_percent_change_from_baseline              -70.365385
# residential_percent_change_from_baseline              29.461538
# dtype: float64

# %%
# Between lockdowns
greater_london.loc['2020-05-14':'2020-08-13'].mean()
# Out:
# retail_and_recreation_percent_change_from_baseline   -57.489130
# grocery_and_pharmacy_percent_change_from_baseline    -19.119565
# parks_percent_change_from_baseline                    40.934783
# transit_stations_percent_change_from_baseline        -59.989130
# workplaces_percent_change_from_baseline              -50.750000
# residential_percent_change_from_baseline              18.728261
# dtype: float64

# %%
# Second lockdown
greater_london.loc['2020-11-05':'2020-12-02'].mean()
# Out:
# retail_and_recreation_percent_change_from_baseline   -61.464286
# grocery_and_pharmacy_percent_change_from_baseline    -16.535714
# parks_percent_change_from_baseline                    -6.500000
# transit_stations_percent_change_from_baseline        -58.857143
# workplaces_percent_change_from_baseline              -44.892857
# residential_percent_change_from_baseline              18.357143
# dtype: float64

# %%
# Third lockdown
greater_london.loc['2020-12-20':'2021-03-08'].mean()
# Out:
# retail_and_recreation_percent_change_from_baseline   -68.253165
# grocery_and_pharmacy_percent_change_from_baseline    -23.987342
# parks_percent_change_from_baseline                   -14.759494
# transit_stations_percent_change_from_baseline        -69.126582
# workplaces_percent_change_from_baseline              -55.278481
# residential_percent_change_from_baseline              22.481013
# dtype: float64

# %% [markdown]
# ## Comparing different London boroughs

# %%
# Looking at difference between boroughs
london_boroughs = pd.concat([london_2020, london_2021]).drop(['country_region_code', 'country_region', 'sub_region_1',
                                                              'metro_area', 'iso_3166_2_code', 'census_fips_code',
                                                              'place_id'], axis=1).set_index('date')

boroughs_l1 = london_boroughs.loc[((london_boroughs.index>'2020-03-23')&(london_boroughs.index<'2020-03-32')|
                                   (london_boroughs.index>'2020-04-00')&(london_boroughs.index<'2020-04-31')|
                                   (london_boroughs.index>'2020-05-00')&(london_boroughs.index<'2020-05-14'))].groupby('sub_region_2').mean()

# %%
# Removing "Borough of" from the start of every Borough name
borough_names = []
for borough in boroughs_l1.index:
    i = borough.find('of')
    if i>0:
        borough_names.append(borough[i+3:])
    else:
        borough_names.append(borough)
borough_names[0] = 'City of London'
print(borough_names)
# Out:
# ['City of London', 'Westminster', 'Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Hackney', 'Hammersmith and Fulham', 'Haringey', 'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington', 'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Greenwich', 'Kensington and Chelsea', 'Kingston upon Thames']

# %%
boroughs_l1.index = borough_names
boroughs_l1.to_csv('datasets/google_boroughs.csv')
