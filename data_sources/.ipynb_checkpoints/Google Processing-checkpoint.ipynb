# %%
import pandas as pd
import numpy as np

# %%
google = pd.read_csv("2020_GB_Region_Mobility_Report.csv")
google
# Out:
#        country_region_code  country_region sub_region_1 sub_region_2  \
# 0                       GB  United Kingdom          NaN          NaN
# 1                       GB  United Kingdom          NaN          NaN
# 2                       GB  United Kingdom          NaN          NaN
# 3                       GB  United Kingdom          NaN          NaN
# 4                       GB  United Kingdom          NaN          NaN
# ...                    ...             ...          ...          ...
# 133377                  GB  United Kingdom         York          NaN
# 133378                  GB  United Kingdom         York          NaN
# 133379                  GB  United Kingdom         York          NaN
# 133380                  GB  United Kingdom         York          NaN
# 133381                  GB  United Kingdom         York          NaN
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 0              NaN             NaN               NaN
# ...

# %%
london = google[google.sub_region_1=='Greater London']
london
# Out:
#       country_region_code  country_region    sub_region_1  \
# 36253                  GB  United Kingdom  Greater London
# 36254                  GB  United Kingdom  Greater London
# 36255                  GB  United Kingdom  Greater London
# 36256                  GB  United Kingdom  Greater London
# 36257                  GB  United Kingdom  Greater London
# ...                   ...             ...             ...
# 47162                  GB  United Kingdom  Greater London
# 47163                  GB  United Kingdom  Greater London
# 47164                  GB  United Kingdom  Greater London
# 47165                  GB  United Kingdom  Greater London
# 47166                  GB  United Kingdom  Greater London
#
#                                 sub_region_2  metro_area iso_3166_2_code  \
# 36253                                    NaN         NaN             NaN
# 36254                                    NaN         NaN             NaN
# ...

# %%
london_all = london[london.sub_region_2]
london_all
# Out:
#   File "<ipython-input-15-ab1ec248c042>", line 1
#     london_all = london[!london.sub_region_2]
#                         ^
# SyntaxError: invalid syntax

# %%
np.isnan(london.sub_region_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-6f9150febf3c> in <module>
# ----> 1 np.isnan(london.sub_region_2)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    1931         self, ufunc: Callable, method: str, *inputs: Any, **kwargs: Any
#    1932     ):
# -> 1933         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    1934
#    1935     # ideally we would define this to avoid the getattr checks, but
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     272         # ufunc(series, ...)
#     273         inputs = tuple(extract_array(x, extract_numpy=True) for x in inputs)
# ...
