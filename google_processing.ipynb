# %% [markdown]
# ## Google COVID-19 Community Mobility Report data

# %%
import pandas as pd
import numpy as np

# %%
google_2020 = pd.read_csv("data_sources/2020_GB_Region_Mobility_Report.csv")
google_2020
# Out:
#        country_region_code  country_region sub_region_1 sub_region_2  \
# 0                       GB  United Kingdom          NaN          NaN
# 1                       GB  United Kingdom          NaN          NaN
# 2                       GB  United Kingdom          NaN          NaN
# 3                       GB  United Kingdom          NaN          NaN
# 4                       GB  United Kingdom          NaN          NaN
# ...                    ...             ...          ...          ...
# 133377                  GB  United Kingdom         York          NaN
# 133378                  GB  United Kingdom         York          NaN
# 133379                  GB  United Kingdom         York          NaN
# 133380                  GB  United Kingdom         York          NaN
# 133381                  GB  United Kingdom         York          NaN
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 0              NaN             NaN               NaN
# 1              NaN             NaN               NaN
# 2              NaN             NaN               NaN
# 3              NaN             NaN               NaN
# 4              NaN             NaN               NaN
# ...            ...             ...               ...
# 133377         NaN          GB-YOR               NaN
# 133378         NaN          GB-YOR               NaN
# 133379         NaN          GB-YOR               NaN
# 133380         NaN          GB-YOR               NaN
# 133381         NaN          GB-YOR               NaN
#
#                            place_id        date  \
# 0       ChIJqZHHQhE7WgIReiWIMkOg-MQ  2020-02-15
# 1       ChIJqZHHQhE7WgIReiWIMkOg-MQ  2020-02-16
# 2       ChIJqZHHQhE7WgIReiWIMkOg-MQ  2020-02-17
# 3       ChIJqZHHQhE7WgIReiWIMkOg-MQ  2020-02-18
# 4       ChIJqZHHQhE7WgIReiWIMkOg-MQ  2020-02-19
# ...                             ...         ...
# 133377  ChIJh-IigLwxeUgRAKFv7Z75DAM  2020-12-27
# 133378  ChIJh-IigLwxeUgRAKFv7Z75DAM  2020-12-28
# 133379  ChIJh-IigLwxeUgRAKFv7Z75DAM  2020-12-29
# 133380  ChIJh-IigLwxeUgRAKFv7Z75DAM  2020-12-30
# 133381  ChIJh-IigLwxeUgRAKFv7Z75DAM  2020-12-31
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                   -12.0
# 1                                                    -7.0
# 2                                                    10.0
# 3                                                     7.0
# 4                                                     6.0
# ...                                                   ...
# 133377                                              -51.0
# 133378                                              -25.0
# 133379                                              -22.0
# 133380                                              -22.0
# 133381                                              -46.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                    -7.0
# 1                                                    -6.0
# 2                                                     1.0
# 3                                                    -1.0
# 4                                                    -2.0
# ...                                                   ...
# 133377                                              -26.0
# 133378                                              -16.0
# 133379                                               -6.0
# 133380                                               -1.0
# 133381                                                3.0
#
#         parks_percent_change_from_baseline  \
# 0                                    -35.0
# 1                                    -28.0
# 2                                     24.0
# 3                                     20.0
# 4                                      8.0
# ...                                    ...
# 133377                               -32.0
# 133378                                21.0
# 133379                                14.0
# 133380                                 7.0
# 133381                                 7.0
#
#         transit_stations_percent_change_from_baseline  \
# 0                                               -12.0
# 1                                                -7.0
# 2                                                -2.0
# 3                                                -3.0
# 4                                                -4.0
# ...                                               ...
# 133377                                          -38.0
# 133378                                          -35.0
# 133379                                          -37.0
# 133380                                          -37.0
# 133381                                          -57.0
#
#         workplaces_percent_change_from_baseline  \
# 0                                          -4.0
# 1                                          -3.0
# 2                                         -14.0
# 3                                         -14.0
# 4                                         -14.0
# ...                                         ...
# 133377                                    -20.0
# 133378                                    -73.0
# 133379                                    -64.0
# 133380                                    -62.0
# 133381                                    -67.0
#
#         residential_percent_change_from_baseline
# 0                                            2.0
# 1                                            1.0
# 2                                            2.0
# 3                                            2.0
# 4                                            3.0
# ...                                          ...
# 133377                                       9.0
# 133378                                      23.0
# 133379                                      21.0
# 133380                                      20.0
# 133381                                      23.0
#
# [133382 rows x 15 columns]

# %%
google_2021 = pd.read_csv("data_sources/2021_GB_Region_Mobility_Report.csv")
google_2021
# Out:
#       country_region_code  country_region sub_region_1 sub_region_2  \
# 0                      GB  United Kingdom          NaN          NaN
# 1                      GB  United Kingdom          NaN          NaN
# 2                      GB  United Kingdom          NaN          NaN
# 3                      GB  United Kingdom          NaN          NaN
# 4                      GB  United Kingdom          NaN          NaN
# ...                   ...             ...          ...          ...
# 64784                  GB  United Kingdom         York          NaN
# 64785                  GB  United Kingdom         York          NaN
# 64786                  GB  United Kingdom         York          NaN
# 64787                  GB  United Kingdom         York          NaN
# 64788                  GB  United Kingdom         York          NaN
#
#        metro_area iso_3166_2_code  census_fips_code  \
# 0             NaN             NaN               NaN
# 1             NaN             NaN               NaN
# 2             NaN             NaN               NaN
# 3             NaN             NaN               NaN
# 4             NaN             NaN               NaN
# ...           ...             ...               ...
# 64784         NaN          GB-YOR               NaN
# 64785         NaN          GB-YOR               NaN
# 64786         NaN          GB-YOR               NaN
# 64787         NaN          GB-YOR               NaN
# 64788         NaN          GB-YOR               NaN
#
#                           place_id        date  \
# 0      ChIJqZHHQhE7WgIReiWIMkOg-MQ  2021-01-01
# 1      ChIJqZHHQhE7WgIReiWIMkOg-MQ  2021-01-02
# 2      ChIJqZHHQhE7WgIReiWIMkOg-MQ  2021-01-03
# 3      ChIJqZHHQhE7WgIReiWIMkOg-MQ  2021-01-04
# 4      ChIJqZHHQhE7WgIReiWIMkOg-MQ  2021-01-05
# ...                            ...         ...
# 64784  ChIJh-IigLwxeUgRAKFv7Z75DAM  2021-05-31
# 64785  ChIJh-IigLwxeUgRAKFv7Z75DAM  2021-06-01
# 64786  ChIJh-IigLwxeUgRAKFv7Z75DAM  2021-06-02
# 64787  ChIJh-IigLwxeUgRAKFv7Z75DAM  2021-06-03
# 64788  ChIJh-IigLwxeUgRAKFv7Z75DAM  2021-06-04
#
#        retail_and_recreation_percent_change_from_baseline  \
# 0                                                  -83.0
# 1                                                  -68.0
# 2                                                  -64.0
# 3                                                  -53.0
# 4                                                  -61.0
# ...                                                  ...
# 64784                                               20.0
# 64785                                               21.0
# 64786                                               15.0
# 64787                                               14.0
# 64788                                               -2.0
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                  -64.0
# 1                                                  -24.0
# 2                                                  -24.0
# 3                                                  -17.0
# 4                                                  -21.0
# ...                                                  ...
# 64784                                               14.0
# 64785                                               31.0
# 64786                                               23.0
# 64787                                               24.0
# 64788                                               19.0
#
#        parks_percent_change_from_baseline  \
# 0                                    -5.0
# 1                                   -12.0
# 2                                    -8.0
# 3                                   -16.0
# 4                                   -18.0
# ...                                   ...
# 64784                               222.0
# 64785                               177.0
# 64786                               157.0
# 64787                               133.0
# 64788                                93.0
#
#        transit_stations_percent_change_from_baseline  \
# 0                                              -82.0
# 1                                              -66.0
# 2                                              -62.0
# 3                                              -62.0
# 4                                              -63.0
# ...                                              ...
# 64784                                          -16.0
# 64785                                          -16.0
# 64786                                          -22.0
# 64787                                          -23.0
# 64788                                          -20.0
#
#        workplaces_percent_change_from_baseline  \
# 0                                        -83.0
# 1                                        -39.0
# 2                                        -29.0
# 3                                        -49.0
# 4                                        -50.0
# ...                                        ...
# 64784                                    -74.0
# 64785                                    -50.0
# 64786                                    -49.0
# 64787                                    -47.0
# 64788                                    -46.0
#
#        residential_percent_change_from_baseline
# 0                                          32.0
# 1                                          16.0
# 2                                          11.0
# 3                                          19.0
# 4                                          20.0
# ...                                         ...
# 64784                                      13.0
# 64785                                       9.0
# 64786                                      10.0
# 64787                                      10.0
# 64788                                       8.0
#
# [64789 rows x 15 columns]

# %%
london_2020 = google_2020[google_2020.sub_region_1=='Greater London']
london_2021 = google_2021[google_2021.sub_region_1=='Greater London']

# %%
greater_london = pd.concat([london_2020[london_2020.sub_region_2.astype('str')=='nan'],
                            london_2021[london_2021.sub_region_2.astype('str')=='nan']]) 
greater_london
# Out:
#       country_region_code  country_region    sub_region_1 sub_region_2  \
# 36253                  GB  United Kingdom  Greater London          NaN
# 36254                  GB  United Kingdom  Greater London          NaN
# 36255                  GB  United Kingdom  Greater London          NaN
# 36256                  GB  United Kingdom  Greater London          NaN
# 36257                  GB  United Kingdom  Greater London          NaN
# ...                   ...             ...             ...          ...
# 17798                  GB  United Kingdom  Greater London          NaN
# 17799                  GB  United Kingdom  Greater London          NaN
# 17800                  GB  United Kingdom  Greater London          NaN
# 17801                  GB  United Kingdom  Greater London          NaN
# 17802                  GB  United Kingdom  Greater London          NaN
#
#        metro_area iso_3166_2_code  census_fips_code  \
# 36253         NaN             NaN               NaN
# 36254         NaN             NaN               NaN
# 36255         NaN             NaN               NaN
# 36256         NaN             NaN               NaN
# 36257         NaN             NaN               NaN
# ...           ...             ...               ...
# 17798         NaN             NaN               NaN
# 17799         NaN             NaN               NaN
# 17800         NaN             NaN               NaN
# 17801         NaN             NaN               NaN
# 17802         NaN             NaN               NaN
#
#                           place_id        date  \
# 36253  ChIJb-IaoQug2EcRi-m4hONz8S8  2020-02-15
# 36254  ChIJb-IaoQug2EcRi-m4hONz8S8  2020-02-16
# 36255  ChIJb-IaoQug2EcRi-m4hONz8S8  2020-02-17
# 36256  ChIJb-IaoQug2EcRi-m4hONz8S8  2020-02-18
# 36257  ChIJb-IaoQug2EcRi-m4hONz8S8  2020-02-19
# ...                            ...         ...
# 17798  ChIJb-IaoQug2EcRi-m4hONz8S8  2021-05-31
# 17799  ChIJb-IaoQug2EcRi-m4hONz8S8  2021-06-01
# 17800  ChIJb-IaoQug2EcRi-m4hONz8S8  2021-06-02
# 17801  ChIJb-IaoQug2EcRi-m4hONz8S8  2021-06-03
# 17802  ChIJb-IaoQug2EcRi-m4hONz8S8  2021-06-04
#
#        retail_and_recreation_percent_change_from_baseline  \
# 36253                                              -11.0
# 36254                                               -9.0
# 36255                                               11.0
# 36256                                                4.0
# 36257                                                3.0
# ...                                                  ...
# 17798                                              -21.0
# 17799                                              -28.0
# 17800                                              -30.0
# 17801                                              -28.0
# 17802                                              -39.0
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 36253                                               -8.0
# 36254                                              -11.0
# 36255                                                4.0
# 36256                                               -2.0
# 36257                                               -3.0
# ...                                                  ...
# 17798                                               -7.0
# 17799                                                3.0
# 17800                                                0.0
# 17801                                                2.0
# 17802                                               -8.0
#
#        parks_percent_change_from_baseline  \
# 36253                               -34.0
# 36254                               -41.0
# 36255                                28.0
# 36256                                11.0
# 36257                                 3.0
# ...                                   ...
# 17798                               140.0
# 17799                                73.0
# 17800                                61.0
# 17801                                64.0
# 17802                               -20.0
#
#        transit_stations_percent_change_from_baseline  \
# 36253                                          -10.0
# 36254                                           -9.0
# 36255                                           -3.0
# 36256                                           -4.0
# 36257                                           -5.0
# ...                                              ...
# 17798                                          -55.0
# 17799                                          -48.0
# 17800                                          -48.0
# 17801                                          -48.0
# 17802                                          -48.0
#
#        workplaces_percent_change_from_baseline  \
# 36253                                     -3.0
# 36254                                     -4.0
# 36255                                    -13.0
# 36256                                    -13.0
# 36257                                    -13.0
# ...                                        ...
# 17798                                    -76.0
# 17799                                    -53.0
# 17800                                    -51.0
# 17801                                    -51.0
# 17802                                    -49.0
#
#        residential_percent_change_from_baseline
# 36253                                       2.0
# 36254                                       1.0
# 36255                                       2.0
# 36256                                       2.0
# 36257                                       3.0
# ...                                         ...
# 17798                                      14.0
# 17799                                      12.0
# 17800                                      13.0
# 17801                                      13.0
# 17802                                      14.0
#
# [476 rows x 15 columns]

# %%
greater_london.drop(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
                     'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id'], axis=1, inplace=True)
greater_london.set_index('date', inplace=True)

# %%
greater_london.to_csv('datasets/google_greater_london.csv')

# %%
greater_london
# Out:
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-02-15                                              -11.0
# 2020-02-16                                               -9.0
# 2020-02-17                                               11.0
# 2020-02-18                                                4.0
# 2020-02-19                                                3.0
# ...                                                       ...
# 2021-05-31                                              -21.0
# 2021-06-01                                              -28.0
# 2021-06-02                                              -30.0
# 2021-06-03                                              -28.0
# 2021-06-04                                              -39.0
#
#             grocery_and_pharmacy_percent_change_from_baseline  \
# date
# 2020-02-15                                               -8.0
# 2020-02-16                                              -11.0
# 2020-02-17                                                4.0
# 2020-02-18                                               -2.0
# 2020-02-19                                               -3.0
# ...                                                       ...
# 2021-05-31                                               -7.0
# 2021-06-01                                                3.0
# 2021-06-02                                                0.0
# 2021-06-03                                                2.0
# 2021-06-04                                               -8.0
#
#             parks_percent_change_from_baseline  \
# date
# 2020-02-15                               -34.0
# 2020-02-16                               -41.0
# 2020-02-17                                28.0
# 2020-02-18                                11.0
# 2020-02-19                                 3.0
# ...                                        ...
# 2021-05-31                               140.0
# 2021-06-01                                73.0
# 2021-06-02                                61.0
# 2021-06-03                                64.0
# 2021-06-04                               -20.0
#
#             transit_stations_percent_change_from_baseline  \
# date
# 2020-02-15                                          -10.0
# 2020-02-16                                           -9.0
# 2020-02-17                                           -3.0
# 2020-02-18                                           -4.0
# 2020-02-19                                           -5.0
# ...                                                   ...
# 2021-05-31                                          -55.0
# 2021-06-01                                          -48.0
# 2021-06-02                                          -48.0
# 2021-06-03                                          -48.0
# 2021-06-04                                          -48.0
#
#             workplaces_percent_change_from_baseline  \
# date
# 2020-02-15                                     -3.0
# 2020-02-16                                     -4.0
# 2020-02-17                                    -13.0
# 2020-02-18                                    -13.0
# 2020-02-19                                    -13.0
# ...                                             ...
# 2021-05-31                                    -76.0
# 2021-06-01                                    -53.0
# 2021-06-02                                    -51.0
# 2021-06-03                                    -51.0
# 2021-06-04                                    -49.0
#
#             residential_percent_change_from_baseline
# date
# 2020-02-15                                       2.0
# 2020-02-16                                       1.0
# 2020-02-17                                       2.0
# 2020-02-18                                       2.0
# 2020-02-19                                       3.0
# ...                                              ...
# 2021-05-31                                      14.0
# 2021-06-01                                      12.0
# 2021-06-02                                      13.0
# 2021-06-03                                      13.0
# 2021-06-04                                      14.0
#
# [476 rows x 6 columns]

# %%
# First lockdown
greater_london.loc['2020-03-23':'2020-05-13'].mean()
# Out:
# retail_and_recreation_percent_change_from_baseline   -79.653846
# grocery_and_pharmacy_percent_change_from_baseline    -33.653846
# parks_percent_change_from_baseline                   -17.326923
# transit_stations_percent_change_from_baseline        -76.403846
# workplaces_percent_change_from_baseline              -70.365385
# residential_percent_change_from_baseline              29.461538
# dtype: float64

# %%
# Between lockdowns
greater_london.loc['2020-05-14':'2020-08-13'].mean()
# Out:
# retail_and_recreation_percent_change_from_baseline   -57.489130
# grocery_and_pharmacy_percent_change_from_baseline    -19.119565
# parks_percent_change_from_baseline                    40.934783
# transit_stations_percent_change_from_baseline        -59.989130
# workplaces_percent_change_from_baseline              -50.750000
# residential_percent_change_from_baseline              18.728261
# dtype: float64

# %%
# Second lockdown
greater_london.loc['2020-11-05':'2020-12-02'].mean()
# Out:
# retail_and_recreation_percent_change_from_baseline   -61.464286
# grocery_and_pharmacy_percent_change_from_baseline    -16.535714
# parks_percent_change_from_baseline                    -6.500000
# transit_stations_percent_change_from_baseline        -58.857143
# workplaces_percent_change_from_baseline              -44.892857
# residential_percent_change_from_baseline              18.357143
# dtype: float64

# %%
# Third lockdown
greater_london.loc['2020-12-20':'2021-03-08'].mean()
# Out:
# retail_and_recreation_percent_change_from_baseline   -68.253165
# grocery_and_pharmacy_percent_change_from_baseline    -23.987342
# parks_percent_change_from_baseline                   -14.759494
# transit_stations_percent_change_from_baseline        -69.126582
# workplaces_percent_change_from_baseline              -55.278481
# residential_percent_change_from_baseline              22.481013
# dtype: float64

# %% [markdown]
# ## Comparing different London boroughs

# %%
# Looking at difference between boroughs
london_boroughs = pd.concat([london_2020, london_2021]).drop(['country_region_code', 'country_region', 'sub_region_1',
                                                              'metro_area', 'iso_3166_2_code', 'census_fips_code',
                                                              'place_id'], axis=1).set_index('date')

boroughs_l1 = london_boroughs.loc[((london_boroughs.index>'2020-03-23')&(london_boroughs.index<'2020-03-32')|
                                   (london_boroughs.index>'2020-04-00')&(london_boroughs.index<'2020-04-31')|
                                   (london_boroughs.index>'2020-05-00')&(london_boroughs.index<'2020-05-14'))].groupby('sub_region_2').mean()

# %%
# Removing "Borough of" from the start of every Borough name
borough_names = []
for borough in boroughs_l1.index:
    i = borough.find('of')
    if i>0:
        borough_names.append(borough[i+3:])
    else:
        borough_names.append(borough)
borough_names[0] = 'City of London'
print(borough_names)
# Out:
# ['City of London', 'Westminster', 'Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Hackney', 'Hammersmith and Fulham', 'Haringey', 'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington', 'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Greenwich', 'Kensington and Chelsea', 'Kingston upon Thames']

# %%
boroughs_l1.index = borough_names
boroughs_l1.to_csv('datasets/google_boroughs.csv')
